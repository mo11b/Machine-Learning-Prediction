# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('realtor-data.csv')
df.head()
# Out:
#      status     price  bed  bath  acre_lot
# 0  for_sale  105000.0  3.0   2.0      0.12  \
# 1  for_sale   80000.0  4.0   2.0      0.08
# 2  for_sale   67000.0  2.0   1.0      0.15
# 3  for_sale  145000.0  4.0   2.0      0.10
# 4  for_sale   65000.0  6.0   2.0      0.05
#
#                                         full_address
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601  \
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico  \
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# ...

# %%
df = df[['price','bed','bath','acre_lot','state','house_size']]
df.head()
# Out:
#       price  bed  bath  acre_lot        state  house_size
# 0  105000.0  3.0   2.0      0.12  Puerto Rico       920.0
# 1   80000.0  4.0   2.0      0.08  Puerto Rico      1527.0
# 2   67000.0  2.0   1.0      0.15  Puerto Rico       748.0
# 3  145000.0  4.0   2.0      0.10  Puerto Rico      1800.0
# 4   65000.0  6.0   2.0      0.05  Puerto Rico         NaN

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# price         0
# bed           0
# bath          0
# acre_lot      0
# state         0
# house_size    0
# dtype: int64

# %%
df.shape
# Out:
# (319642, 6)

# %%
df = df[['price','bed','bath','state','house_size']]
df.head()
# Out:
#       price  bed  bath        state  house_size
# 0  105000.0  3.0   2.0  Puerto Rico       920.0
# 1   80000.0  4.0   2.0  Puerto Rico      1527.0
# 2   67000.0  2.0   1.0  Puerto Rico       748.0
# 3  145000.0  4.0   2.0  Puerto Rico      1800.0
# 5  179000.0  4.0   3.0  Puerto Rico      2520.0

# %%
fig, ax = plt.subplots(1,1, figsize= (12, 7))
df.boxplot ('bed', 'state', ax=ax)
plt.suptitle('bed v state')
plt.title('')
plt.ylabel('bed')
plt.xticks(rotation=90)
plt.show()

# %%
df = df[df["bed"] <= 8]
df = df[df["bed"] >= 1]
fig, ax = plt.subplots(1,1, figsize= (12, 7))
df.boxplot ('bed', 'state', ax=ax)
plt.suptitle('bed v state')
plt.title('')
plt.ylabel('bed')
plt.xticks(rotation=90)
plt.show()

# %%
df = df[df["state"] != 'West Virginia']
df = df[df["state"] != 'Wyoming']
df['state'].unique()
# Out:
# array(['Puerto Rico', 'Virgin Islands', 'Massachusetts', 'Connecticut',
#        'New Jersey', 'New York', 'New Hampshire', 'Vermont',
#        'Rhode Island', 'Maine', 'Pennsylvania', 'Delaware'], dtype=object)

# %%
fig, ax = plt.subplots(1,1, figsize= (12, 7))
df.boxplot ('bath', 'state', ax=ax)
plt.suptitle('bath v state')
plt.title('')
plt.ylabel('bath')
plt.xticks(rotation=90)
plt.show()

# %%
df = df[df["bath"] <= 8]
df = df[df["bath"] >= 1]
fig, ax = plt.subplots(1,1, figsize= (12, 7))
df.boxplot ('bath', 'state', ax=ax)
plt.suptitle('bath v state')
plt.title('')
plt.ylabel('bath')
plt.xticks(rotation=90)
plt.show()

# %%
df.describe()
# Out:
#               price            bed           bath    house_size
# count  3.086430e+05  308643.000000  308643.000000  3.086430e+05
# mean   6.888610e+05       3.599541       2.551874  2.304719e+03
# std    9.714466e+05       1.327988       1.265565  3.376765e+03
# min    3.900000e+03       1.000000       1.000000  1.220000e+02
# 25%    2.799000e+05       3.000000       2.000000  1.330500e+03
# 50%    4.490000e+05       3.000000       2.000000  1.892000e+03
# 75%    7.450000e+05       4.000000       3.000000  2.738000e+03
# max    4.990000e+07       8.000000       8.000000  1.450112e+06

# %%
df = df[df["house_size"] <= 11000]
fig, ax = plt.subplots(1,1, figsize= (12, 7))
df.boxplot ('house_size', 'state', ax=ax)
plt.suptitle('house_size v state')
plt.title('')
plt.ylabel('house_size')
plt.xticks(rotation=90)
plt.show()

# %%
df.describe()
# Out:
#               price            bed           bath     house_size
# count  3.073550e+05  307355.000000  307355.000000  307355.000000
# mean   6.851324e+05       3.592442       2.546502    2216.366205
# std    9.466446e+05       1.321245       1.260301    1300.298393
# min    3.900000e+03       1.000000       1.000000     122.000000
# 25%    2.799000e+05       3.000000       2.000000    1328.000000
# 50%    4.488000e+05       3.000000       2.000000    1884.000000
# 75%    7.415000e+05       4.000000       3.000000    2724.000000
# max    4.990000e+07       8.000000       8.000000   11000.000000

# %%
df = df[df["price"] <= 1000000]
fig, ax = plt.subplots(1,1, figsize= (12, 7))
df.boxplot ('price', 'state', ax=ax)
plt.suptitle('price v state')
plt.title('')
plt.ylabel('price')
plt.xticks(rotation=90)
plt.show()

# %%
df.describe()
# Out:
#                 price            bed           bath     house_size
# count   264744.000000  264744.000000  264744.000000  264744.000000
# mean    435453.207540       3.459757       2.294432    1957.589358
# std     229205.560607       1.257364       0.995513     973.158461
# min       3900.000000       1.000000       1.000000     122.000000
# 25%     259000.000000       3.000000       2.000000    1266.000000
# 50%     392500.000000       3.000000       2.000000    1750.000000
# 75%     596000.000000       4.000000       3.000000    2423.000000
# max    1000000.000000       8.000000       8.000000   10998.000000

# %%
dummies = pd.get_dummies(df.state)
dummies.head(3)
# Out:
#    Connecticut  Delaware  Maine  Massachusetts  New Hampshire  New Jersey
# 0        False     False  False          False          False       False  \
# 1        False     False  False          False          False       False
# 2        False     False  False          False          False       False
#
#    New York  Pennsylvania  Puerto Rico  Rhode Island  Vermont  Virgin Islands
# 0     False         False         True         False    False           False
# 1     False         False         True         False    False           False
# 2     False         False         True         False    False           False

# %%
df = pd.concat([df, dummies], axis=1)
df.head()
# Out:
#       price  bed  bath        state  house_size  Connecticut  Delaware  Maine
# 0  105000.0  3.0   2.0  Puerto Rico       920.0        False     False  False  \
# 1   80000.0  4.0   2.0  Puerto Rico      1527.0        False     False  False
# 2   67000.0  2.0   1.0  Puerto Rico       748.0        False     False  False
# 3  145000.0  4.0   2.0  Puerto Rico      1800.0        False     False  False
# 5  179000.0  4.0   3.0  Puerto Rico      2520.0        False     False  False
#
#    Massachusetts  New Hampshire  New Jersey  New York  Pennsylvania
# 0          False          False       False     False         False  \
# 1          False          False       False     False         False
# 2          False          False       False     False         False
# 3          False          False       False     False         False
# 5          False          False       False     False         False
#
#    Puerto Rico  Rhode Island  Vermont  Virgin Islands
# ...

# %%
df = df.drop('state',axis='columns')
df.head()
# Out:
#       price  bed  bath  house_size  Connecticut  Delaware  Maine
# 0  105000.0  3.0   2.0       920.0        False     False  False  \
# 1   80000.0  4.0   2.0      1527.0        False     False  False
# 2   67000.0  2.0   1.0       748.0        False     False  False
# 3  145000.0  4.0   2.0      1800.0        False     False  False
# 5  179000.0  4.0   3.0      2520.0        False     False  False
#
#    Massachusetts  New Hampshire  New Jersey  New York  Pennsylvania
# 0          False          False       False     False         False  \
# 1          False          False       False     False         False
# 2          False          False       False     False         False
# 3          False          False       False     False         False
# 5          False          False       False     False         False
#
#    Puerto Rico  Rhode Island  Vermont  Virgin Islands
# 0         True         False    False           False
# 1         True         False    False           False
# ...

# %%
df.shape
# Out:
# (264744, 16)

# %%
X = df.drop(['price'],axis='columns')
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
reg.score(X_test,y_test)
# Out:
# 0.41561769554457506

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.41810903, 0.40786306, 0.41481398, 0.41480827, 0.41425935])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3204529604949650.5, tolerance: 1113710728364.8442
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3139666321610538.0, tolerance: 1112935712265.5283
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 414572932434180.5, tolerance: 1112095421997.3955
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor()
reg.fit(X_train,y_train)
reg.score(X_test,y_test)
# Out:
# 0.8935486829782602

# %%
X
# Out:
#         bed  bath  house_size  Connecticut  Delaware  Maine  Massachusetts
# 0       3.0   2.0       920.0        False     False  False          False  \
# 1       4.0   2.0      1527.0        False     False  False          False
# 2       2.0   1.0       748.0        False     False  False          False
# 3       4.0   2.0      1800.0        False     False  False          False
# 5       4.0   3.0      2520.0        False     False  False          False
# ...     ...   ...         ...          ...       ...    ...            ...
# 613136  3.0   3.0      1697.0        False     False  False          False
# 613137  1.0   1.0       882.0        False     False  False          False
# 613143  4.0   2.0      1950.0        False     False  False          False
# 613146  7.0   4.0      2965.0        False     False  False          False
# 613149  4.0   4.0      3200.0        False     False  False          False
#
# ...

# %%
import numpy as np
def predict_price(state,bed,bath,house_size):    
    loc_index = np.where(X.columns==state)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = bed
    x[1] = bath
    x[2] = house_size
    if loc_index >= 0:
        x[loc_index] = 1

    return reg.predict([x])[0]

# %%
predict_price('New York',3,2,748)
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# 639900.0

# %%
import pickle
with open('prices_model.pickle','wb') as f:
    pickle.dump(reg,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
